# %% [markdown]
# # 機械学習・データ分析(2019)  課題3（期末課題）
#
# ### このnotebookには、いくつかの設問が記載されています。
# ### 先頭から順番に、指示に従ってPython Codeをcellに記述してください。
# ### codeを記述するcellは、各自適切に生成してください。
# ### ぜひ、楽しみながら課題に取り組んでください。
#
#
#
# ## <span style="color: red; ">課題提出期限
# # <span style="color: red; ">2019年7月1日（月）17時30分
#
#
# ## 課題提出方法
# ### 各自のGitHubに、学籍番号_MD3（たとえば、C180001_MD3）という名称のrepositoryを作成してください。
# ### このnotebookを各自のGitHubのリポジトリ（学籍番号_MD3)へコピーしてください。
# ### このnotebookに記載されたcodeは、データファイルtitanic.csvを参照しています。そこで、このデータファイルも必ずGitHubのリポジトリへコピーしてください。
# ### このnotebookに記載されたcodeがデータファイルを参照している場合、そのデータファイルも必ずGitHubのRepositoryへコピーしてください。
# ### 各自のGitHubのリポジトリをoffice 365のメールアカウントを使用して、sugimura@ccg.ac.jpへ送信してください。メールの件名は、学籍番号_MD3としてください。
# ### 【重要】指定された方法で課題を提出することも課題に含まれています。

# %% [markdown]
# ## 【設問1】
# ### データ分析では、データが欠損していること（一部のデータが欠けていること）があります。欠損したままのデータを処理すると、たとえば、平均値などの結果に正しい値が得られなくなります。そのため、欠損値は除外することが必要になります。
# ### 欠損値は、numpyモジュールにおけるnumpy.nanという特別な値で表現することができます。
# ### 課題２で使用したDataFrame型のオブジェクトattr1_dataframe1を使って、データの欠損について学びます。

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

attr1 = {'ID':['100', '102', '104', '106', '108'],
         'City':['Tokyo', 'Osaka', 'Kyoto', 'Hokkaido', 'Tokyo'],
         'Birth_year':[1990, 1989, 1992, 1997, 1982],
         'Name':['Hiroshi', 'Akiko', 'Yuki', 'Satoru', 'Steeve']}

attr1_dataframe1 = DataFrame(attr1)
attr1_dataframe1
# Out:
#     ID      City  Birth_year     Name
# 0  100     Tokyo        1990  Hiroshi
# 1  102     Osaka        1989    Akiko
# 2  104     Kyoto        1992     Yuki
# 3  106  Hokkaido        1997   Satoru
# 4  108     Tokyo        1982   Steeve

# %% [markdown]
# ### 【設問１－１】解答
# #### データattr1_dataframe1のすべての要素の中に、Tokyoという文字列が存在するかどうかをisinメソッドを使って調べてください。
# #### isinを用いると、要素にTokyoが含まれているとき、Trueを表示し、要素にTokyoが含まれていないとき、Falseを表示します。

# %%
#第1-1問
attr1_dataframe1.isin(['Tokyo'])
# Out:
#       ID   City  Birth_year   Name
# 0  False   True       False  False
# 1  False  False       False  False
# 2  False  False       False  False
# 3  False  False       False  False
# 4  False   True       False  False

# %% [markdown]
# ### 【設問１－２】解答
# #### データattr1_dataframe1の列Nameの値をすべてnanに変更した新しいデータattr1_dataframe2を作成し、画面に表示させてください。

# %%
#第1-2問
attr1_dataframe2 = attr1_dataframe1.replace(['Hiroshi','Akiko','Yuki','Satoru','Steeve'],np.nan)
attr1_dataframe2
# Out:
#     ID      City  Birth_year  Name
# 0  100     Tokyo        1990   NaN
# 1  102     Osaka        1989   NaN
# 2  104     Kyoto        1992   NaN
# 3  106  Hokkaido        1997   NaN
# 4  108     Tokyo        1982   NaN

# %% [markdown]
# ### 【設問１－３】解答
# #### データattr1_dataframe2の要素がnanであるかどうかを調べてください。
# #### データの要素がnanであるかどうかは、isnull()メソッドによって判定することができます。
# #### たとえば、DataFrame型データdfの要素がnanであるかどうかは、df.isnull()によって調べることができます。

# %% [markdown]
# ### 列Nameのすべての要素がTrueになりましたか？
# ### 列ごとのnanの個数は、nanを判定し、Trueの数を合計すれば求めることができます。
# ### 以下の結果を確認して下さい。

# %%
#第1-3問
attr1_dataframe2.isnull().sum()
# Out:
# ID            0
# City          0
# Birth_year    0
# Name          5
# dtype: int64

# %% [markdown]
# ### 列Nameにおけるnanの個数が５個であることを確認できたはずです。

# %% [markdown]
# ## 【設問２】
# ### 関数を定義し、関数のグラフを描画しましょう。
# ### 描画する関数は、
#
# $$f(x) = x ^ 2 + 2x + 1 $$
#
# ### という二次関数です。
# ### Jupyter Notebook中にグラフを描画するため、いつも通りにいくつかのモジュールをインポートして準備しましょう。

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### 【設問２－１】解答
# #### 二次関数f(x)を定義してください。関数名は、function_1(x)としてください。

# %%
#第2-1問
x = np.arange(-10, 10)
function_1 = x**2 + 2*x + 1
plt.plot(x, function_1)
plt.show()

# %% [markdown]
# ### 【設問２－２】解答
# #### 関数f(x)におけるxは、-10から+10までの値を取り得るものとします。このxの範囲をnp.arange(下限値, 上限値)を使って定義してください。
# #### arrangeではなく、arangeであることに注意してください。

# %% [markdown]
# ### では、関数のグラフを描画しましょう。

# %%
#第2-2問
plt.figure(figsize=(10, 4))
plt.plot(x, function_1)
plt.grid(True)

# %% [markdown]
# ### 【設問２－３】
# ### 次の関数
#
# $$f(x) = - x ^ 2 - 2x + 1 $$
#
# ### を描画してください。
# ### ただし、xは、-20から+20までの値を取り得るものとします。

# %%
#第2-3問
x = np.arange(-20, 20)
function_2 = -x**2 - 2*x + 1
plt.plot(x, function_2)
plt.show()

# %% [markdown]
# ## 【設問３】
# ### Pandasを使ってcsvファイルを読み込み、統計量を計算しましょう。
# ### 読み込むファイルは、titanic.csvです。
#
# ### 【設問３－１】解答
# #### titanic.csvをDataFrame型データに読み込み、先頭の５行を表示させてください。

# %%
#第3-1問
import pandas as pd
import numpy as np

ict2019_1 = pd.read_csv('titanic.csv')
ict2019_1.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# ### 【設問３－２】解答
# #### Titanic号の乗員の年齢構成を調べ、
# + 9歳以下　　 　〇〇人
# + 10歳から19歳　〇〇人
# * 20歳から29歳　〇〇人
# * 30歳から39歳　〇〇人
# + 40歳から49歳　〇〇人
# + 50歳から59歳　〇〇人
# + 60歳から69歳　〇〇人
# + 70歳以上　　　〇〇人
# #### のように表示しなさい。

# %%
#第3-2問
a1 = 0
a2 = 0
a3 = 0
a4 = 0
a5 = 0
a6 = 0
a7 = 0
a8 = 0

for a in ict2019_1['Age']:
    if a < 10:
        a1 += 1
    elif a > 9 and a < 20:
        a2 += 1
    elif a > 19 and a < 30:
        a3 += 1
    elif a > 29 and a < 40:
        a4 += 1
    elif a > 39 and a < 50:
        a5 += 1
    elif a > 49 and a < 60:
        a6 += 1
    elif a > 59 and a < 70:
        a7 += 1
    elif a > 69 :
        a8 += 1

print('9歳以下 ' + str(a1) + '人')
print('10歳から19歳 ' + str(a2) + '人')
print('20歳から29歳 ' + str(a3) + '人')
print('30歳から39歳 ' + str(a4) + '人')
print('40歳から49歳 ' + str(a5) + '人')
print('50歳から59歳 ' + str(a6) + '人')
print('60歳から69歳 ' + str(a7) + '人')
print('70歳以上 ' + str(a8) + '人')
# Out:
# 9歳以下 62人
# 10歳から19歳 102人
# 20歳から29歳 397人
# 30歳から39歳 167人
# 40歳から49歳 89人
# 50歳から59歳 48人
# 60歳から69歳 19人
# 70歳以上 7人

# %% [markdown]
# ### 【設問３－３】解答
# #### 設問３－２で求めた年齢構成を円グラフで表してください。

# %%
#第3-3問
import numpy as np
import matplotlib.pyplot as plt
x = np.array([62, 102, 397, 167, 89, 48, 19, 7])
label = ["< = 9", "10-19", "20-29", "30-39", "40-49", "50-59", "60-69", "> = 70"]
plt.pie(x, labels=label)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc98311c8d0>,
#   <matplotlib.patches.Wedge at 0x7fc98311ce48>,
#   <matplotlib.patches.Wedge at 0x7fc983124358>,
#   <matplotlib.patches.Wedge at 0x7fc983124828>,
#   <matplotlib.patches.Wedge at 0x7fc983124cf8>,
#   <matplotlib.patches.Wedge at 0x7fc98312f208>,
#   <matplotlib.patches.Wedge at 0x7fc98312f6d8>,
#   <matplotlib.patches.Wedge at 0x7fc98312fba8>],
#  [Text(1.0738205717778413, 0.2385568687477059, '< = 9'),
#   Text(0.7688534101069459, 0.7866793716419166, '10-19'),
#   Text(-0.9168995799249663, 0.6076966022065784, '20-29'),
#   Text(-0.18336918569844987, -1.0846085661363216, '30-39'),
#   Text(0.7377713726989423, -0.8159003625602322, '40-49'),
#   Text(1.032328919252181, -0.3798644527665419, '50-59'),
#   Text(1.092562188921801, -0.12770224484480677, '60-69'),
#   Text(1.0996649710908288, -0.0271468479902709, '> = 70')])

# %% [markdown]
# ### 【設問３－４】解答
# #### 生存者の年齢構成を【設問３－３】と同様に円グラフで表してください。

# %%
#第3-4問
import numpy as np
import matplotlib.pyplot as plt
x = np.array([38, 41, 129, 73, 34, 20, 6, 1])
label = ["< = 9", "10-19", "20-29", "30-39", "40-49", "50-59", "60-69", "> = 70"]
plt.pie(x, labels=label)
# Out:
# ([<matplotlib.patches.Wedge at 0x7fc9830ef080>,
#   <matplotlib.patches.Wedge at 0x7fc9830ef5f8>,
#   <matplotlib.patches.Wedge at 0x7fc9830efac8>,
#   <matplotlib.patches.Wedge at 0x7fc9830eff98>,
#   <matplotlib.patches.Wedge at 0x7fc9830f84a8>,
#   <matplotlib.patches.Wedge at 0x7fc9830f8978>,
#   <matplotlib.patches.Wedge at 0x7fc9830f8e48>,
#   <matplotlib.patches.Wedge at 0x7fc983082358>],
#  [Text(1.0336618818860421, 0.3762221603465248, '< = 9'),
#   Text(0.5235421359161693, 0.9674211243922347, '10-19'),
#   Text(-0.9625711288899359, 0.5324066320281469, '20-29'),
#   Text(-0.24054925233847138, -1.0733760092341371, '30-39'),
#   Text(0.7597514424545172, -0.7954732840820492, '40-49'),
#   Text(1.0467848881186699, -0.3379961508751005, '50-59'),
#   Text(1.0970311037356821, -0.08076358979435669, '60-69'),
#   Text(1.0999535902329414, -0.010104421490752373, '> = 70')])

# %% [markdown]
# # 以上で期末課題は終了です。お疲れさまでした。
